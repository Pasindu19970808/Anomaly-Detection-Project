# %%
from pyod.models.copod import COPOD
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import re
import pyod
import pyod.models.auto_encoder_torch as ae
import pyod.models.cblof as cblof
import pyod.models.knn as knn
# from dao import DataLoading

# Potentially added at a later point, but need it install SUOD on Conda
# import pyod.models.suod as SUOD

# %%
def plot_results(data, anamoly_score, threshold, anamoly_pos, title, file_to_load):
    
    fig, (ax1, ax2) = plt.subplots(2)
    fig.suptitle(title)
    ax1.plot(total[0:threshold], color = 'gray')
    ax1.plot(total[threshold:], color = 'blue')
    ax1.set_ylabel('Value')
    ax1.axvline(threshold, label='threshold', color = 'black')
    ax1.axvline(anamoly_pos, label='predicted anamoly', color = 'red')
    ax2.plot(anamoly_score[0:threshold], color = 'gray')
    ax2.plot(anamoly_score[threshold:], color = 'blue')
    ax2.set_ylabel('Anamoly Score')
    ax2.axvline(threshold, label='threshold', color = 'black')
    ax2.axvline(anamoly_pos, label='predicted anamoly', color = 'red')
    plt.show()

# %%
# Define split data

def split_data(file_path, index):
    file_name = os.listdir(file_path)[index]
    test_data_start_pt = int(re.findall(
        r'[0-9]*.txt', file_name)[0].split('.')[0])
    total_data = pd.read_csv(os.path.join(file_path, os.listdir(file_path)[index]))
    train_data = total_data[0:test_data_start_pt]
    test_data = total_data[test_data_start_pt+1:len(total_data)]

    return train_data, test_data, total_data, test_data_start_pt

# %%
def train_models():
    
    # Autoencoder
    anamoly_pos_autoenc, test_outlier_scores_autoenc, prominence_score_autoenc = Detect_AE()

    # Cluster-based Local Outlier Factor
    anamoly_pos_CBLOF, test_outlier_scores_CBLOF, prominence_score_CBLOF = Detect_CBLOF()

    # K-Nearest Neighbors
    anamoly_pos_KNN, test_outlier_scores_KNN, prominence_score_KNN = Detect_KNN()

    # Copula-Based Outlier Detection
    anamoly_pos_COPOD, test_outlier_scores_COPOD, prominence_score_COPOD = Detect_COPOD()
    
    return anamoly_pos_autoenc, anamoly_pos_CBLOF, anamoly_pos_KNN, anamoly_pos_COPOD, prominence_score_autoenc, prominence_score_CBLOF, prominence_score_KNN, prominence_score_COPOD

# %%
def Detect_AE():
    # Implement algorithm #1 (Autoencoding)
    # https://pyod.readthedocs.io/en/latest/pyod.models.html#pyod-models-auto-encoder-module

    # Define model (TBD hidden neuron details...)
    clf = ae.AutoEncoder(epochs = 10)

    # Fit model
    clf.fit(train)
    
    # Determine outlier scores for training data
    train_outlier_scores = clf.decision_scores_
    
    # Determine outlier scores for test data
    test_outlier_scores = clf.decision_function(total)
    test_outlier_scores = pd.Series(test_outlier_scores)
    anamoly_pos = test_outlier_scores[threshold:].idxmax()
    prominence_score = test_outlier_scores.nlargest(2).iloc[0] / test_outlier_scores.nlargest(2).iloc[1]
    print("Predicted Anamoloy from Autoencoder algorithm is located at location: " + str(anamoly_pos))
    
    return anamoly_pos, test_outlier_scores, prominence_score

# %%
def Detect_CBLOF():
    # Implement algorithm #2 (CBLOF)
    outliers_fraction = 0.000000001

    # Define model (TBD hidden neuron details...)
    clf = cblof.CBLOF(contamination=outliers_fraction,check_estimator=False, random_state=0)

    # Fit model
    clf.fit(train)

    # Determine outlier scores for training data
    train_outlier_scores = clf.decision_scores_

    # Determine outlier scores for test data
    test_outlier_scores = clf.decision_function(total)
    test_outlier_scores = pd.Series(test_outlier_scores)
    anamoly_pos = test_outlier_scores[threshold:].idxmax()
    prominence_score = test_outlier_scores.nlargest(2).iloc[0] / test_outlier_scores.nlargest(2).iloc[1]
    print("Predicted Anamoloy from CBLOF algorithm is located at location: " + str(anamoly_pos))
    
    return anamoly_pos, test_outlier_scores, prominence_score

# %%
def Detect_KNN():
    # Implement algorithm #3 (K-Nearest Neighbors)
    outliers_fraction = 0.000000001

    # Define model (TBD hidden neuron details...)
    clf = knn.KNN(contamination=outliers_fraction)

    # Fit model
    clf.fit(train)

    # Determine outlier scores for training data
    train_outlier_scores = clf.decision_scores_

    # Determine outlier scores for test data
    test_outlier_scores = clf.decision_function(total)
    test_outlier_scores = pd.Series(test_outlier_scores)
    anamoly_pos = test_outlier_scores[threshold:].idxmax()
    prominence_score = test_outlier_scores.nlargest(2).iloc[0] / test_outlier_scores.nlargest(2).iloc[1]
    print("Predicted anamoloy from KNN algorithm is located at location: " + str(anamoly_pos))
    
    return anamoly_pos, test_outlier_scores, prominence_score

# %%
def Detect_COPOD():    
    # Implement algorithm #4 (COPOD)

    ##### COPOD Algorithm
    clf = COPOD()
    clf.fit(train)

    # Fit model
    clf.fit(train)

    # Determine outlier scores for training data
    train_outlier_scores = clf.decision_scores_

    # Determine outlier scores for test data
    test_outlier_scores = clf.decision_function(total)
    test_outlier_scores = pd.Series(test_outlier_scores)
    anamoly_pos = test_outlier_scores[threshold:].idxmax()
    prominence_score = test_outlier_scores.nlargest(2).iloc[0] / test_outlier_scores.nlargest(2).iloc[1]
    print("Predicted anamoloy from COPOD algorithm  is located at location: " + str(anamoly_pos))
    
    return anamoly_pos, test_outlier_scores, prominence_score

# %%
# Initialize all anamoly lists to be zero

# Filename
file_name_list = []

# Autoencoder
anamoly_pos_autoenc = []
anamoly_prom_autoenc = []

# Cluster-based Local Outlier Factor
anamoly_pos_CBLOF = []
anamoly_prom_CBLOF = []

# K-Nearest Neighbors
anamoly_pos_KNN = []
anamoly_prom_KNN = []

# Copula-Based Outlier Detection
anamoly_pos_COPOD = []
anamoly_prom_COPOD = []

# Ensemble prediction
predicted_voting = []
predicted_prom = []

# for k in range(len(os.listdir(file_path))-1):

# subset for testing purposes
for k in range(10):

# full set
# for k in range(250):
    # define path to data directory
    file_path = os.path.join(os.getcwd(), 'KDD-Cup', 'data')
    file_name = os.listdir(file_path)[k+1]
    file_to_load = os.path.join(file_path, file_name)
    train, test, total, threshold = split_data(file_path, k+1)
    
    print("Analysis started for file " + file_name)
    
    autoenc_pred, CBLOF_pred, KNN_pred, COPOD_pred, autoenc_prom, CBLOF_prom, KNN_prom, COPOD_prom = train_models()
    
    # Add value for each item to list
    file_name_list.append(file_name) 
    anamoly_pos_autoenc.append(autoenc_pred) 
    anamoly_pos_CBLOF.append(CBLOF_pred) 
    anamoly_pos_KNN.append(KNN_pred) 
    anamoly_pos_COPOD.append(COPOD_pred) 
    anamoly_prom_autoenc.append(autoenc_prom) 
    anamoly_prom_CBLOF.append(CBLOF_prom) 
    anamoly_prom_KNN.append(KNN_prom) 
    anamoly_prom_COPOD.append(COPOD_prom) 
    
    # Initially add zero to the list (voting mechanism handled within data frame below)
    predicted_voting.append(0)
    predicted_prom.append(0)
    
    
# Create Data frame of predicted anamolies
predictions = pd.DataFrame({'File Name': file_name_list, 'AutoEncoder': anamoly_pos_autoenc, 'CBLOF':anamoly_pos_CBLOF, 'KNN': anamoly_pos_KNN,'COPOD':anamoly_pos_COPOD, 'AutoEncoder_prom': anamoly_prom_autoenc, 'CBLOF_prom':anamoly_prom_CBLOF, 'KNN_prom': anamoly_prom_KNN, 'COPOD_prom':anamoly_prom_COPOD, 'Predicted_voting': predicted_voting, 'Predicted_prom':predicted_prom} ) 

# Prominence-based voting
predictions['Predicted_prom'] = np.select(
    [
        predictions['AutoEncoder_prom'] >= predictions[['AutoEncoder_prom', 'CBLOF_prom', 'KNN_prom', 'COPOD_prom']].values.max(1),
        predictions['CBLOF_prom'] >= predictions[['AutoEncoder_prom', 'CBLOF_prom', 'KNN_prom', 'COPOD_prom']].values.max(1),
        predictions['KNN_prom'] >= predictions[['AutoEncoder_prom', 'CBLOF_prom', 'KNN_prom', 'COPOD_prom']].values.max(1),
        predictions['COPOD_prom'] >= predictions[['AutoEncoder_prom', 'CBLOF_prom', 'KNN_prom', 'COPOD_prom']].values.max(1)
    ], 
    [
        predictions['AutoEncoder'],
        predictions['CBLOF'],
        predictions['KNN'],
        predictions['COPOD']
    ], 
    default=-9999
)

# Mode-based voting
predictions['Predicted_voting'] = predictions[['AutoEncoder', 'CBLOF', 'KNN', 'COPOD']].mode(axis=1, dropna=False)

# Display data frame
# Create Data frame of predicted anamolies
predictions = pd.DataFrame({'File Name': file_name_list, 'AutoEncoder': anamoly_pos_autoenc, 'CBLOF':anamoly_pos_CBLOF, 'KNN': anamoly_pos_KNN,'COPOD':anamoly_pos_COPOD, 'AutoEncoder_prom': anamoly_prom_autoenc, 'CBLOF_prom':anamoly_prom_CBLOF, 'KNN_prom': anamoly_prom_KNN, 'COPOD_prom':anamoly_prom_COPOD, 'Predicted_voting': predicted_voting, 'Predicted_prom':predicted_prom} ) 

# Prominence-based voting
predictions['Predicted_prom'] = np.select(
    [
        predictions['AutoEncoder_prom'] >= predictions[['AutoEncoder_prom', 'CBLOF_prom', 'KNN_prom', 'COPOD_prom']].values.max(1),
        predictions['CBLOF_prom'] >= predictions[['AutoEncoder_prom', 'CBLOF_prom', 'KNN_prom', 'COPOD_prom']].values.max(1),
        predictions['KNN_prom'] >= predictions[['AutoEncoder_prom', 'CBLOF_prom', 'KNN_prom', 'COPOD_prom']].values.max(1),
        predictions['COPOD_prom'] >= predictions[['AutoEncoder_prom', 'CBLOF_prom', 'KNN_prom', 'COPOD_prom']].values.max(1)
    ], 
    [
        predictions['AutoEncoder'],
        predictions['CBLOF'],
        predictions['KNN'],
        predictions['COPOD']
    ], 
    default=-9999
)

# Mode-based voting
predictions['Predicted_voting'] = predictions[['AutoEncoder', 'CBLOF', 'KNN', 'COPOD']].mode(axis=1, dropna=False)

# Display data frame
predictions
# Out:
# Analysis started for file 001_UCR_Anomaly_35000.txt
# inner_autoencoder(
#   (activation): ReLU()
#   (encoder): Sequential(
#     (batch_norm0): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=1, out_features=64, bias=True)
#     (relu0): ReLU()
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=32, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
#   (decoder): Sequential(
#     (batch_norm0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=32, out_features=64, bias=True)
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=1, bias=True)
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
# )
# epoch 0: training loss 16.65870382188661
# epoch 1: training loss 15.938610034407384
# epoch 2: training loss 14.90446302256593
# epoch 3: training loss 15.244914098130284
# epoch 4: training loss 15.30276821518293
# epoch 5: training loss 14.823280286745353
# epoch 6: training loss 15.034077653501326
# epoch 7: training loss 14.889276163451632
# epoch 8: training loss 15.159838895802087
# epoch 9: training loss 14.635140105400922
# Predicted Anamoloy from Autoencoder algorithm is located at location: 66888
# Predicted Anamoloy from CBLOF algorithm is located at location: 66888
# Predicted anamoloy from KNN algorithm is located at location: 71184
# Predicted anamoloy from COPOD algorithm  is located at location: 66888
# Analysis started for file 002_UCR_Anomaly_35000.txt
# inner_autoencoder(
#   (activation): ReLU()
#   (encoder): Sequential(
#     (batch_norm0): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=1, out_features=64, bias=True)
#     (relu0): ReLU()
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=32, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
#   (decoder): Sequential(
#     (batch_norm0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=32, out_features=64, bias=True)
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=1, bias=True)
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
# )
# epoch 0: training loss 18.983697796543513
# epoch 1: training loss 16.934225308393867
# epoch 2: training loss 16.518024134570545
# epoch 3: training loss 16.337006450135267
# epoch 4: training loss 15.99246170642825
# epoch 5: training loss 16.07711856543909
# epoch 6: training loss 16.008837576758054
# epoch 7: training loss 15.875009294728692
# epoch 8: training loss 15.665433453794371
# epoch 9: training loss 15.56123200936117
# Predicted Anamoloy from Autoencoder algorithm is located at location: 71390
# Predicted Anamoloy from CBLOF algorithm is located at location: 67095
# Predicted anamoloy from KNN algorithm is located at location: 67095
# Predicted anamoloy from COPOD algorithm  is located at location: 67095
# Analysis started for file 003_UCR_Anomaly_35000.txt
# inner_autoencoder(
#   (activation): ReLU()
#   (encoder): Sequential(
#     (batch_norm0): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=1, out_features=64, bias=True)
#     (relu0): ReLU()
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=32, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
#   (decoder): Sequential(
#     (batch_norm0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=32, out_features=64, bias=True)
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=1, bias=True)
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
# )
# epoch 0: training loss 17.22514614500991
# epoch 1: training loss 16.258343670987124
# epoch 2: training loss 15.9698313543304
# epoch 3: training loss 16.229240124524186
# epoch 4: training loss 15.798050204077413
# epoch 5: training loss 15.713317852188071
# epoch 6: training loss 15.32178363383797
# epoch 7: training loss 15.671544760738039
# epoch 8: training loss 15.761893293430425
# epoch 9: training loss 15.203304208392852
# Predicted Anamoloy from Autoencoder algorithm is located at location: 67094
# Predicted Anamoloy from CBLOF algorithm is located at location: 71389
# Predicted anamoloy from KNN algorithm is located at location: 67094
# Predicted anamoloy from COPOD algorithm  is located at location: 67094
# Analysis started for file 004_UCR_Anomaly_2500.txt
# inner_autoencoder(
#   (activation): ReLU()
#   (encoder): Sequential(
#     (batch_norm0): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=1, out_features=64, bias=True)
#     (relu0): ReLU()
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=32, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
#   (decoder): Sequential(
#     (batch_norm0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=32, out_features=64, bias=True)
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=1, bias=True)
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
# )
# epoch 0: training loss 17.008194066301176
# epoch 1: training loss 11.117961120001878
# epoch 2: training loss 11.533988946600806
# epoch 3: training loss 10.074066853221458
# epoch 4: training loss 10.422822493541089
# epoch 5: training loss 10.236633988875377
# epoch 6: training loss 10.643525257895265
# epoch 7: training loss 11.361310546911216
# epoch 8: training loss 11.651659014858778
# epoch 9: training loss 11.000509986394569
# Predicted Anamoloy from Autoencoder algorithm is located at location: 5590
# Predicted Anamoloy from CBLOF algorithm is located at location: 5590
# Predicted anamoloy from KNN algorithm is located at location: 5590
# Predicted anamoloy from COPOD algorithm  is located at location: 5590
# Analysis started for file 005_UCR_Anomaly_4000.txt
# inner_autoencoder(
#   (activation): ReLU()
#   (encoder): Sequential(
#     (batch_norm0): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=1, out_features=64, bias=True)
#     (relu0): ReLU()
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=32, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
#   (decoder): Sequential(
#     (batch_norm0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=32, out_features=64, bias=True)
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=1, bias=True)
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
# )
# epoch 0: training loss 0.14102274426817893
# epoch 1: training loss 0.07248251861333847
# epoch 2: training loss 0.05964263220131397
# epoch 3: training loss 0.05028682076931
# epoch 4: training loss 0.04584642716497183
# epoch 5: training loss 0.04392621869593859
# epoch 6: training loss 0.04377953977137804
# epoch 7: training loss 0.04148572507500649
# epoch 8: training loss 0.04298939476162195
# epoch 9: training loss 0.04326380529999733
# Predicted Anamoloy from Autoencoder algorithm is located at location: 6253
# Predicted Anamoloy from CBLOF algorithm is located at location: 6253
# Predicted anamoloy from KNN algorithm is located at location: 6254
# Predicted anamoloy from COPOD algorithm  is located at location: 6253
# Analysis started for file 006_UCR_Anomaly_4000.txt
# inner_autoencoder(
#   (activation): ReLU()
#   (encoder): Sequential(
#     (batch_norm0): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=1, out_features=64, bias=True)
#     (relu0): ReLU()
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=32, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
#   (decoder): Sequential(
#     (batch_norm0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=32, out_features=64, bias=True)
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=1, bias=True)
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
# )
# epoch 0: training loss 0.12818260824680328
# epoch 1: training loss 0.0715300663113594
# epoch 2: training loss 0.05296270334720612
# epoch 3: training loss 0.04646165144443512
# epoch 4: training loss 0.04208027976006269
# epoch 5: training loss 0.039780405282974246
# epoch 6: training loss 0.04014977231621742
# epoch 7: training loss 0.03988022792339325
# epoch 8: training loss 0.04247125891596079
# epoch 9: training loss 0.03788442746549845
# Predicted Anamoloy from Autoencoder algorithm is located at location: 5101
# Predicted Anamoloy from CBLOF algorithm is located at location: 5101
# Predicted anamoloy from KNN algorithm is located at location: 6252
# Predicted anamoloy from COPOD algorithm  is located at location: 5101
# Analysis started for file 007_UCR_Anomaly_4000.txt
# inner_autoencoder(
#   (activation): ReLU()
#   (encoder): Sequential(
#     (batch_norm0): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=1, out_features=64, bias=True)
#     (relu0): ReLU()
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=32, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
#   (decoder): Sequential(
#     (batch_norm0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=32, out_features=64, bias=True)
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=1, bias=True)
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
# )
# epoch 0: training loss 0.17351842522621155
# epoch 1: training loss 0.07951589247584342
# epoch 2: training loss 0.05888915471732616
# epoch 3: training loss 0.049257306650280955
# epoch 4: training loss 0.04355789689719677
# epoch 5: training loss 0.038020659528672694
# epoch 6: training loss 0.045530914198607206
# epoch 7: training loss 0.04076446476578712
# epoch 8: training loss 0.0414912866987288
# epoch 9: training loss 0.04011066249758005
# Predicted Anamoloy from Autoencoder algorithm is located at location: 5604
# Predicted Anamoloy from CBLOF algorithm is located at location: 5078
# Predicted anamoloy from KNN algorithm is located at location: 5078
# Predicted anamoloy from COPOD algorithm  is located at location: 5078
# Analysis started for file 008_UCR_Anomaly_4000.txt
# inner_autoencoder(
#   (activation): ReLU()
#   (encoder): Sequential(
#     (batch_norm0): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=1, out_features=64, bias=True)
#     (relu0): ReLU()
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=32, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
#   (decoder): Sequential(
#     (batch_norm0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=32, out_features=64, bias=True)
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=1, bias=True)
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
# )
# epoch 0: training loss 0.13382872620224953
# epoch 1: training loss 0.07245180608332157
# epoch 2: training loss 0.052326185822486874
# epoch 3: training loss 0.04601575734466314
# epoch 4: training loss 0.0403779449313879
# epoch 5: training loss 0.04229096391797066
# epoch 6: training loss 0.043102683126926424
# epoch 7: training loss 0.04316690018773079
# epoch 8: training loss 0.041399753868579865
# epoch 9: training loss 0.03920280699059367
# Predicted Anamoloy from Autoencoder algorithm is located at location: 5171
# Predicted Anamoloy from CBLOF algorithm is located at location: 4791
# Predicted anamoloy from KNN algorithm is located at location: 4790
# Predicted anamoloy from COPOD algorithm  is located at location: 4791
# Analysis started for file 009_UCR_Anomaly_4000.txt
# inner_autoencoder(
#   (activation): ReLU()
#   (encoder): Sequential(
#     (batch_norm0): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=1, out_features=64, bias=True)
#     (relu0): ReLU()
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=32, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
#   (decoder): Sequential(
#     (batch_norm0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=32, out_features=64, bias=True)
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=1, bias=True)
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
# )
# epoch 0: training loss 0.1377600081861019
# epoch 1: training loss 0.0712526227682829
# epoch 2: training loss 0.05453393775224686
# epoch 3: training loss 0.0433621509373188
# epoch 4: training loss 0.04342265116423368
# epoch 5: training loss 0.044402437515556815
# epoch 6: training loss 0.03943680888414383
# epoch 7: training loss 0.04073613239824772
# epoch 8: training loss 0.037553767412900924
# epoch 9: training loss 0.04072138298302889
# Predicted Anamoloy from Autoencoder algorithm is located at location: 8029
# Predicted Anamoloy from CBLOF algorithm is located at location: 6253
# Predicted anamoloy from KNN algorithm is located at location: 6700
# Predicted anamoloy from COPOD algorithm  is located at location: 6253
# Analysis started for file 010_UCR_Anomaly_4000.txt
# inner_autoencoder(
#   (activation): ReLU()
#   (encoder): Sequential(
#     (batch_norm0): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=1, out_features=64, bias=True)
#     (relu0): ReLU()
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=32, bias=True)
#     (relu1): ReLU()
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
#   (decoder): Sequential(
#     (batch_norm0): BatchNorm1d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear0): Linear(in_features=32, out_features=64, bias=True)
#     (dropout0): Dropout(p=0.2, inplace=False)
#     (batch_norm1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (linear1): Linear(in_features=64, out_features=1, bias=True)
#     (dropout1): Dropout(p=0.2, inplace=False)
#   )
# )
# epoch 0: training loss 0.11332988482713699
# epoch 1: training loss 0.0646361469477415
# epoch 2: training loss 0.04667018400132656
# epoch 3: training loss 0.044891760170459746
# epoch 4: training loss 0.04291840797662735
# epoch 5: training loss 0.03998401587456465
# epoch 6: training loss 0.040064296685159206
# epoch 7: training loss 0.03968216896802187
# epoch 8: training loss 0.041404639512300494
# epoch 9: training loss 0.040297774598002434
# Predicted Anamoloy from Autoencoder algorithm is located at location: 5101
# Predicted Anamoloy from CBLOF algorithm is located at location: 5101
# Predicted anamoloy from KNN algorithm is located at location: 5101
# Predicted anamoloy from COPOD algorithm  is located at location: 5101
#                    File Name  AutoEncoder  CBLOF    KNN  COPOD  \
# 0  001_UCR_Anomaly_35000.txt        66888  66888  71184  66888
# 1  002_UCR_Anomaly_35000.txt        71390  67095  67095  67095
# 2  003_UCR_Anomaly_35000.txt        67094  71389  67094  67094
# 3   004_UCR_Anomaly_2500.txt         5590   5590   5590   5590
# 4   005_UCR_Anomaly_4000.txt         6253   6253   6254   6253
# 5   006_UCR_Anomaly_4000.txt         5101   5101   6252   5101
# 6   007_UCR_Anomaly_4000.txt         5604   5078   5078   5078
# 7   008_UCR_Anomaly_4000.txt         5171   4791   4790   4791
# 8   009_UCR_Anomaly_4000.txt         8029   6253   6700   6253
# 9   010_UCR_Anomaly_4000.txt         5101   5101   5101   5101
#
#    AutoEncoder_prom  CBLOF_prom  KNN_prom  COPOD_prom  Predicted_voting  \
# 0          1.002745    1.001774  1.119512    1.063256             66888
# 1          1.098935    1.012925  1.084305    1.063246             67095
# 2          1.026981    1.041123  1.056425    1.063246             67094
# 3          1.036519    1.010809  1.020513    1.078613              5590
# 4          1.010987    1.029672  1.309945    1.086411              6253
# 5          1.034727    1.021937  1.159905    1.086411              5101
# 6          1.000095    1.015862  1.084188    1.086411              5078
# 7          1.000100    1.001247  1.006973    1.086411              4791
# 8          1.000269    1.008614  1.071063    1.086411              6253
# 9          1.001076    1.005557  1.053841    1.132217              5101
#
#    Predicted_prom
# 0           71184
# 1           71390
# 2           67094
# 3            5590
# 4            6254
# 5            6252
# 6            5078
# 7            4791
# 8            6253
# 9            5101

# %%
# Creation of final prediction file
submission_file = pd.DataFrame()
submission_file['No.'] = predictions['File Name'].str[:3].astype('int32')
submission_file['Location of Anomaly'] = predictions['Predicted_prom']
submission_file.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_aa6da_" ><thead>    <tr>        <th class="col_heading level0 col0" >No.</th>        <th class="col_heading level0 col1" >Location of Anomaly</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_aa6da_row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_aa6da_row0_col1" class="data row0 col1" >71184</td>
#             </tr>
#             <tr>
#                                 <td id="T_aa6da_row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_aa6da_row1_col1" class="data row1 col1" >71390</td>
#             </tr>
#             <tr>
#                                 <td id="T_aa6da_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_aa6da_row2_col1" class="data row2 col1" >67094</td>
#             </tr>
#             <tr>
#                                 <td id="T_aa6da_row3_col0" class="data row3 col0" >4</td>
#                         <td id="T_aa6da_row3_col1" class="data row3 col1" >5590</td>
#             </tr>
#             <tr>
#                                 <td id="T_aa6da_row4_col0" class="data row4 col0" >5</td>
#                         <td id="T_aa6da_row4_col1" class="data row4 col1" >6254</td>
#             </tr>
#             <tr>
#                                 <td id="T_aa6da_row5_col0" class="data row5 col0" >6</td>
#                         <td id="T_aa6da_row5_col1" class="data row5 col1" >6252</td>
#             </tr>
#             <tr>
#                                 <td id="T_aa6da_row6_col0" class="data row6 col0" >7</td>
#                         <td id="T_aa6da_row6_col1" class="data row6 col1" >5078</td>
#             </tr>
#             <tr>
#                                 <td id="T_aa6da_row7_col0" class="data row7 col0" >8</td>
#                         <td id="T_aa6da_row7_col1" class="data row7 col1" >4791</td>
#             </tr>
#             <tr>
#                                 <td id="T_aa6da_row8_col0" class="data row8 col0" >9</td>
#                         <td id="T_aa6da_row8_col1" class="data row8 col1" >6253</td>
#             </tr>
#             <tr>
#                                 <td id="T_aa6da_row9_col0" class="data row9 col0" >10</td>
#                         <td id="T_aa6da_row9_col1" class="data row9 col1" >5101</td>
#             </tr>
#     </tbody></table>

# %%
#### Below for development purposes ####
print(file_name)

# Autoencoder
anamoly_pos_autoenc, test_outlier_scores_autoenc, prom_autoenc = Detect_AE()

# Cluster-based Local Outlier Factor
anamoly_pos_CBLOF, test_outlier_scores_CBLOF, prom_CBLOF = Detect_CBLOF()

# K-Nearest Neighbors
anamoly_pos_KNN, test_outlier_scores_KNN, prom_KNN = Detect_KNN()

# Copula-Based Outlier Detection
anamoly_pos_COPOD, test_outlier_scores_COPOD, prom_COPOD = Detect_COPOD()

# %%
# Plot results
plot_results(total, test_outlier_scores_autoenc, threshold, anamoly_pos_autoenc, "Auto Encoder Anomoly Scores", file_to_load)

# %%
# Plot results
plot_results(total, test_outlier_scores_CBLOF, threshold, anamoly_pos_CBLOF, "Cluster-based Local Outlier Factor Anomoly Scores", file_to_load)

# %%
# Plot results
plot_results(total, test_outlier_scores_KNN, threshold, anamoly_pos_KNN, "K-Nearest Neighbors Anomoly Scores", file_to_load)

# %%
# Plot
plot_results(total, test_outlier_scores_COPOD, threshold, anamoly_pos_COPOD, "Copula-Based Outlier Detection Anomoly Scores", file_to_load)
